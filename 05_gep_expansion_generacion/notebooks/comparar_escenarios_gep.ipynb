# %% [markdown]
# # Datos GEP multianual
#
# Notebook de exploración de datos para la asignatura.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
base=Path('..')/'actividades'
tech=pd.read_csv(base/'datos_actividad_05_tecnologias.csv')
print(tech)
tech.plot(x='tecnologia', y=['capex_kusd_mw','costo_variable_usd_mwh'], kind='bar', figsize=(8,4))
plt.title('CAPEX y costo variable')
plt.tight_layout(); plt.show()
