# %% [markdown]
# # Exploración de datos — Operación
#
# Notebook de exploración de datos para la asignatura.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
base=Path('..')/'actividades'
gen=pd.read_csv(base/'datos_actividad_02_generadores.csv')
dem=pd.read_csv(base/'datos_actividad_02_demanda.csv')
print(gen); print(dem)
dem.plot(x='hora', y='demanda_mw', marker='o')
plt.title('Curva de demanda horaria')
plt.grid(True); plt.tight_layout(); plt.show()
